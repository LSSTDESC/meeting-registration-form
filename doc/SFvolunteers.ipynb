# %% [markdown]
# This notebook demonstrates how to query for Session Facilitator volunteers from the PostgreSQL database belonging to a Heroku app.

# %%
from sqlalchemy import create_engine
import pandas as pd

# %% [markdown]
# The database connection information is read from a protected file, here called
# `database.ini`.  Only the owner should be able to access the file.
# The contents should be the value of the Heroku config variable `DATABASE_URL`,
# except that, depending on the version of sqlalchemy you're using, you may
# have to change the initial part `postgres:` to `postgresql:`
#
# If `database.ini` is not in the same folder as the notebook, specify
# the path.

# %%
with open('database.ini','r') as f:
    db_string = f.read().strip()

    db = create_engine(db_string)

# %% [markdown]
# Aside: query the names of all columns in the 'participants' table

# %%
Q="SELECT COLUMN_NAME \
FROM INFORMATION_SCHEMA.COLUMNS \
WHERE TABLE_NAME = 'participants' \
ORDER BY ORDINAL_POSITION;"
print("Q = ",Q)
# Out:
# Q =  SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'participants' ORDER BY ORDINAL_POSITION;

# %%
with db.connect() as conn:
    cols = pd.read_sql_query(Q, conn)

# %%
cols
# Out:
#         column_name
# 0                id
# 1        first_name
# 2         last_name
# 3             email
# 4       affiliation
# 5      early_career
# 6         in_person
# 7              site
# 8             lname
# 9             sname
# 10          pronoun
# 11           sprint
# 12           poster
# 13        de_school
# 14          contact
# 15        volunteer
# 16               CL
# 17              DKM
# 18              MCP
# 19              PLC
# 20               PO
# 21               PZ
# 22              SCS
# 23               SC
# 24               TD
# 25             WLSS
# 26           Social
# 27        recording
# 28  code_of_conduct
# 29        speedchat

# %%
# This is will retrieve the list of people wishing to volunteer as session facilitator
with db.connect() as conn:
    volunteer = pd.read_sql_query(
        "select * from participants where volunteer = 'on' order by last_name;", conn)

# %%
# Write the csv list to disk (for importing to a spreadsheet)
volunteer.to_csv("SFs.csv")
# Display the list below
volunteer
# Out:
#     id     first_name       last_name                              email  \
# 0   80       Prakruth           Adari      prakruth.adari@stonybrook.edu
# 1   64         Avijit            Bera           avijit.bera@utdallas.edu
# 2   16       Patricia         Burchat               burchat@stanford.edu
# 3   81  John Franklin        Crenshaw                       jfc20@uw.edu
# 4   70      Dominique         Fouchez              fouchez@cppm.in2p3.fr
# 5    5       Christos        Georgiou                  cgeorgiou@ifae.es
# 6   26          Tesla         Jeltema                     tesla@ucsc.edu
# 7   17        Richard         Kessler          kessler@kicp.uchicago.edu
# 8   14    Shun-Sheng               Li                  liss@stanford.edu
# 9   45           Sean        MacBride        sean.macbride@physik.uzh.ch
# 10   6       Chauncey         Murphey              murphey2@illinois.edu
# 11  31        Jeffrey          Newman                  janewman@pitt.edu
# 12  56           Eske        Pedersen       eskepedersen@fas.harvard.edu
# 13  38       Corentin          Ravoux  corentin.ravoux@clermont.in2p3.fr
# 14  82           Paul      Rogozenski            progozen@andrew.cmu.edu
# 15  43          Nacho  Sevilla Noarbe          ignacio.sevilla@ciemat.es
# 16  23      Tae-hyeon            Shin            taehyeos@andrew.cmu.edu
# 17  28         Connor           Stone           connorstone628@gmail.com
# 18  59         Holden          Truman                   trumanh@msoe.edu
# 19  66         Amanda       Wasserman              amandaw8@illinois.edu
# 20   9         Prince           Yadav              princey2@illinois.edu
# 21  10       Tianqing           Zhang                tq96zhang@gmail.com
#
#                                           affiliation early_career in_person  \
# 0                              Stony Brook University         None      None
# 1                   The University of Texas at Dallas         None      None
# 2                                 Stanford University         None      None
# 3                                               KIPAC         None      None
# 4                                   CPPM - CNRS/IN2P3         None      None
# 5                                                IFAE         None      None
# 6                                       UC Santa Cruz         None      None
# 7                               University of Chicago         None      None
# 8                                               KIPAC         None      None
# 9                                University of Zurich         None      None
# 10                             University of Illinois         None      None
# 11                          U. Pittsburgh / PITT PACC         None      None
# 12                               Newcastle University         None      None
# 13                   LPCA Clermont-Ferrand CNRS/IN2P3         None      None
# 14                         Carnegie Mellon University         None      None
# 15                                             CIEMAT         None      None
# 16                         Carnegie Mellon University         None      None
# 17                              University of Toronto         None      None
# 18                    Milwaukee School of Engineering         None      None
# 19            University of Illinois Urbana-Champaign         None      None
# 20  PhD Student at UIUC under Prof. Xin Liu resear...         None      None
# 21                           University of Pittsburgh         None      None
#
#       site lname sname  ...    PO    PZ   SCS    SC    TD  WLSS Social  \
# 0   Remote  None  None  ...    on    on  None  None  None    on   None
# 1   Remote  None  None  ...  None  None  None  None  None    on   None
# 2   Remote  None  None  ...    on  None  None  None  None    on     on
# 3   Remote  None  None  ...  None    on  None  None  None    on   None
# 4   Remote  None  None  ...  None  None  None  None    on  None   None
# 5   Remote  None  None  ...  None  None  None  None  None    on   None
# 6   Remote  None  None  ...  None  None  None  None  None  None   None
# 7   Remote  None  None  ...  None    on  None    on    on  None   None
# 8   Remote  None  None  ...    on  None  None  None  None    on   None
# 9   Remote  None  None  ...  None  None  None    on    on  None   None
# 10  Remote  None  None  ...  None  None  None    on    on  None     on
# 11  Remote  None  None  ...  None    on  None  None  None  None   None
# 12  Remote  None  None  ...  None    on  None  None  None    on   None
# 13  Remote  None  None  ...  None  None  None    on    on  None   None
# 14  Remote  None  None  ...  None    on  None  None  None    on   None
# 15  Remote  None  None  ...  None    on  None  None  None    on   None
# 16  Remote  None  None  ...    on    on  None  None  None    on   None
# 17  Remote  None  None  ...  None  None  None  None    on  None   None
# 18  Remote  None  None  ...  None    on  None  None    on    on   None
# 19  Remote  None  None  ...  None  None  None  None    on  None   None
# 20  Remote  None  None  ...    on    on  None  None  None  None     on
# 21  Remote  None  None  ...    on    on  None  None  None    on     on
#
#    recording code_of_conduct speedchat
# 0         on              on       yes
# 1         on              on      None
# 2         on              on      None
# 3         on              on      None
# 4         on              on      None
# 5         on              on      None
# 6         on              on      None
# 7         on              on      None
# 8         on              on      None
# 9         on              on      None
# 10        on              on       yes
# 11        on              on      None
# 12        on              on       yes
# 13        on              on      None
# 14        on              on       yes
# 15        on              on      None
# 16        on              on      None
# 17        on              on       yes
# 18        on              on       yes
# 19        on              on      None
# 20        on              on       yes
# 21        on              on       yes
#
# [22 rows x 30 columns]
